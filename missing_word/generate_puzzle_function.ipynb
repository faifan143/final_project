# %%
sentences = {
 'A': {'She occasionally sobs when recalling sad memories.': ['sobs','recalling'],
  'He initiates humanitarian missions.': ['initiates', 'humanitarian'],
  "He likes to eavesdrop on his neighbor's conversations.": ['eavesdrop'],
  'The scientist will scrutinize the research findings.': ['scientist',
   'scrutinize',
   'research'],
  'The couple chortles at a funny joke.': ['couple', 'chortles'],
  'The scientist discovers a new species.': ['scientist'],
  'The conductor guides the orchestra with precision.': ['conductor',
   'orchestra'],
  'She sculpts a masterpiece from clay.': ['sculpts', 'masterpiece'],
  'She explores new hiking trails in the mountains.': ['explores',
   'hiking',
   'trails'],
  'He ambles through the park, enjoying the scenery.': ['ambles', 'enjoying'],
  'He likes to converse with people from different cultures.': ['converse',
   'people'],
  'They research cutting-edge medical treatments.': ['research',
   'cutting-edge'],
  'He designs innovative solutions for his clients.': ['designs',
   'innovative',
   'solutions'],
  'She directs a blockbuster movie production.': ['directs',
   'blockbuster',
   'movie'],
  'She implements a comprehensive healthcare system.': ['implements',
   'healthcare'],
  'She fastens her seatbelt before driving.': ['fastens', 'seatbelt'],
  'She coordinates disaster relief efforts.': ['coordinates',
   'disaster',
   'relief'],
  'The coach motivates the team to victory.': ['coach', 'team'],
  'He constructs innovative green energy solutions.': ['constructs',
   'innovative',
   'energy'],
  'She interprets ancient manuscripts.': ['interprets', 'ancient'],
  'They negotiate international peace agreements.': ['negotiate', 'peace'],
  'He strategizes marketing campaigns.': ['strategizes', 'marketing'],
  'He pioneers breakthroughs in scientific research.': ['pioneers',
   'breakthroughs'],
  'She supervises a multinational corporation.': ['supervises'],
  'The CEO oversees global operations.': ['CEO', 'oversees'],
  'She patents groundbreaking inventions.': ['patents', 'groundbreaking'],
  'They doze off during the long train ride.': ['doze'],
  'He constructs a model of the solar system.': ['constructs', 'model'],
  'They compose music for a new film soundtrack.': ['compose',
   'music',
   'film'],
  'He orchestrates a diplomatic summit.': ['orchestrates'],
  'He unfastens his seatbelt to exit the car.': ['unfastens',
   'seatbelt',
   'exit'],
  'He negotiates a complex business deal.': ['negotiates', 'business'],
  'They navigate through a dense forest.': ['navigate'],
  'The chemist will purify the sample.': ['purify'],
  'They sauté the vegetables in a hot pan.': ['sauté', 'vegetables'],
  'He conducts a psychological study.': ['conducts'],
  'He vaults over the high bar with finesse.': ['vaults', 'bar'],
  'She reclines on the beach, soaking up the sun.': ['reclines', 'soaking'],
  'The lawyer litigates a high-profile case.': ['lawyer'],
  'He composes poetry in his free time.': ['composes', 'poetry'],
  'She researches the history of ancient civilizations.': ['researches',
   'history',
   'ancient'],
  'The children frolic in the park, laughing and playing.': ['children',
   'frolic'],
  'They fabricate intricate jewelry.': ['fabricate', 'intricate'],
  'The surgeon performs a delicate procedure.': ['surgeon',
   'performs',
   'delicate'],
  'The dancers twirl gracefully on the stage.': ['twirl'],
  'She takes a nap on the cozy couch.': ['nap'],
  'They gambol through the meadow, full of energy.': ['gambol'],
  'He reclines on the hammock in the garden.': ['reclines', 'hammock'],
  'She will transcribe the interview recording.': ['transcribe'],
  'They monitor the security cameras closely.': ['monitor'],
  'They administer a large-scale vaccination program.': ['administer',
   'vaccination'],
  'She plans to monitor the progress of the project closely.': ['monitor',
   'project'],
  'The hiker will wade across the shallow river.': ['wade'],
  'He conducts experiments in the laboratory.': ['conducts', 'experiments'],
  'The chef prepares a gourmet meal for the guests.': ['chef', 'meal'],
  'They negotiate a business deal with a client.': ['negotiate',
   'business',
   'deal'],
  'The tugboat will tow the larger ship.': ['tow'],
  'They synthesize organic compounds in the lab.': ['synthesize', 'compounds'],
  'He engineers a cutting-edge technology.': ['engineers', 'cutting-edge'],
  "She examines the patient's medical history.": ['examines'],
  'The artist sculpts sculptures from rare materials.': ['artist',
   'sculpts',
   'sculptures'],
  'She sears the steak to perfection.': ['steak'],
  'She scrutinizes the painting in detail.': ['scrutinizes', 'painting'],
  'They design innovative solutions for their clients.': ['design',
   'innovative',
   'solutions'],
  'He calculates complex equations for his research.': ['calculates',
   'equations'],
  'They analyze financial data for investment decisions.': ['analyze', 'data'],
  'They assemble a team to complete the project.': ['assemble',
   'team',
   'complete'],
  'The detective eavesdrops on a suspicious conversation.': ['detective'],
  'She gazes at the stars in wonder.': ['gazes', 'stars'],
  'She immerses herself in a good book.': ['immerses'],
  'She pirouettes gracefully on the stage.': ['pirouettes'],
  'The architect drafts plans for a new building.': ['architect'],
  'She strategizes marketing campaigns.': ['strategizes', 'marketing'],
  'She negotiates a complex business deal.': ['negotiates', 'business'],
  'We often loiter around the mall on weekends.': ['loiter', 'mall'],
  "He strokes the cat's fur gently.": ['strokes', 'fur'],
  'They analyze market trends for investment.': ['analyze',
   'market',
   'trends'],
  'She evaluates the performance of her employees.': ['evaluates',
   'performance'],
  'The pilot navigates the plane through turbulent skies.': ['pilot',
   'navigates',
   'plane'],
  'He optimizes supply chain logistics.': ['optimizes', 'supply', 'chain'],
  'She programs software to solve real-world problems.': ['programs',
   'software',
   'solve'],
  'She darts through the crowded city streets.': ['city'],
  'They propel the boat forward with oars.': ['propel'],
  'She administers medication to her patients.': ['administers', 'medication'],
  'He caresses the strings of his guitar.': ['caresses', 'strings'],
  'He coordinates the logistics of the event.': ['coordinates', 'logistics'],
  'He organizes a charity fundraiser.': ['organizes', 'charity'],
  'The architect designs sustainable buildings.': ['architect', 'designs'],
  'He repairs broken appliances at home.': ['repairs', 'appliances'],
  'The engineer develops advanced robotics.': ['engineer'],
  'They research the history of ancient civilizations.': ['research',
   'history',
   'ancient'],
  'He wanders through the ancient ruins.': ['wanders', 'ancient'],
  'She coordinates the logistics of the event.': ['coordinates', 'logistics'],
  'She directs a play at the local theater.': ['directs', 'play'],
  'He programs software to solve real-world problems.': ['programs',
   'software',
   'solve'],
  'After work, he likes to lounge on the sofa and watch TV.': ['lounge',
   'sofa',
   'watch'],
  'They consume a delicious meal at the restaurant.': ['consume', 'meal'],
  'He overhears an interesting conversation.': ['overhears'],
  'She implements new policies in the company.': ['implements', 'policies'],
  'During the storm, the ship began to tumble in the rough seas.': ['ship',
   'tumble'],
  'She cleanses her face with a gentle scrub.': ['cleanses', 'face', 'gentle'],
  'They discourse on various topics during dinner.': ['discourse'],
  'She chuckles at the amusing story.': ['chuckles', 'amusing'],
  'The detective analyzes the clues at the crime scene.': ['detective',
   'analyzes',
   'clues'],
  'She trains diligently for the upcoming marathon.': ['trains'],
  'He inspects the machinery for any issues.': ['inspects', 'machinery'],
  'She impels her team to achieve their goals.': ['impels', 'team', 'achieve'],
  'They navigate through complex legal regulations.': ['navigate'],
  'The secretary will record the meeting minutes.': ['secretary',
   'record',
   'meeting'],
  'They linger in the park after sunset.': ['linger', 'park'],
  'He unlatches the gate to the garden.': ['unlatches', 'gate'],
  "I will oversee the project's progress.": ['oversee'],
  'They weep during sad movies.': ['weep'],
  'The scientist will analyze the data collected.': ['scientist',
   'analyze',
   'data'],
  'A skilled spider, patiently spinning a delicate web to ensnare its prey, a marvel of engineering and patience.': ['skilled',
   'delicate',
   'its',
   'marvel'],
  'A library bathed in soft, diffused light, its shelves adorned with books of infinite knowledge, inviting exploration and discovery.': ['library',
   'its',
   'adorned',
   'books',
   'exploration'],
  'An umbrella unfurled against a downpour, a steadfast shield against the elements, a symbol of preparedness.': ['umbrella',
   'shield',
   'symbol'],
  'A lavishly set table, adorned with fine china, crystal glasses, and gleaming silverware, a symbol of hospitality and celebration.': ['lavishly',
   'set',
   'adorned',
   'gleaming',
   'symbol',
   'hospitality'],
  'An intrepid astronaut, clad in a spacesuit, floating amidst the breathtaking vastness of the cosmos, the epitome of human exploration.': ['intrepid',
   'clad',
   'floating',
   'breathtaking',
   'vastness',
   'epitome'],
  "A towering giraffe, gracefully reaching for the tender leaves of a tall acacia tree, a testament to nature's diversity.": ['towering',
   'reaching',
   'tender',
   'leaves',
   'acacia',
   'testament'],
  'A gentle cow, peacefully grazing in a sun-drenched pasture, a symbol of pastoral tranquility.': ['gentle',
   'grazing',
   'symbol'],
  'A talented artist, immersed in a canvas of colors, creating a visual masterpiece that speaks to the heart and stirs the soul.': ['talented',
   'immersed',
   'canvas',
   'creating',
   'masterpiece',
   'speaks',
   'heart',
   'stirs'],
  'A magnificent bird in mid-flight, wings outstretched, capturing the essence of freedom and soaring aspirations.': ['bird',
   'wings',
   'capturing',
   'essence',
   'soaring'],
  'A regal chair at a grand dining table, its ornate design a testament to craftsmanship and elegance.': ['chair',
   'dining',
   'its',
   'design',
   'testament'],
  'An elite athlete in the heat of competition, pushing the boundaries of human performance, inspiring us to achieve greatness.': ['athlete',
   'pushing',
   'boundaries',
   'inspiring',
   'achieve'],
  'A contented chicken, nestled in a cozy coop, its clucking a soothing backdrop to farm life.': ['contented',
   'its',
   'soothing',
   'farm'],
  "A meticulously annotated book, its pages adorned with dog-eared corners, handwritten annotations, and highlighted passages, offering a glimpse into the reader's deep engagement with its contents.": ['meticulously',
   'annotated',
   'its',
   'pages',
   'adorned',
   'highlighted',
   'offering',
   'glimpse',
   'engagement',
   'its'],
  'A refrigerator door adorned with family photos, drawings, and reminders, a hub of household life and memories.': ['refrigerator',
   'door',
   'adorned',
   'family',
   'life'],
  'A bounding kangaroo, effortlessly leaping across the arid Australian landscape, a symbol of adaptability and resilience.': ['bounding',
   'leaping',
   'symbol',
   'adaptability'],
  "A formidable crocodile, lurking beneath the surface of a murky swamp, a testament to nature's primal power.": ['formidable',
   'lurking',
   'surface',
   'murky',
   'testament'],
  'A majestic seagull, soaring effortlessly above the ocean, its cries a part of the coastal symphony.': ['majestic',
   'soaring',
   'its',
   'cries',
   'part'],
  'A contented cat, curled up on a sun-drenched windowsill, its purring a soothing serenade to a peaceful day.': ['contented',
   'curled',
   'its',
   'purring',
   'soothing',
   'serenade'],
  "A skilled mechanic beneath a car's hood, hands deftly working to breathe new life into a mechanical marvel, a guardian of automotive dreams.": ['skilled',
   'mechanic',
   'hands',
   'working',
   'life'],
  'A bustling schoolyard, filled with the infectious laughter and curiosity of children, a playground for friendships, learning, and growth.': ['bustling',
   'filled',
   'laughter',
   'curiosity',
   'playground'],
  'A passionate musician, pouring heart and soul into a song, their voice and instrument merging into a harmonious melody that resonates deeply.': ['passionate',
   'pouring',
   'heart',
   'soul',
   'voice',
   'instrument',
   'merging',
   'melody',
   'resonates'],
  'A sinuous snake, its scales shimmering in the dappled sunlight as it gracefully winds its way through the branches.': ['sinuous',
   'its',
   'scales',
   'shimmering',
   'sunlight',
   'winds',
   'its',
   'way'],
  'A porcupine, its quills bristling with sharpness, a formidable deterrent to would-be predators.': ['its',
   'quills',
   'bristling',
   'formidable',
   'deterrent'],
  'A sleek car, its polished exterior gleaming in the soft glow of a setting sun, a symbol of automotive excellence.': ['sleek',
   'its',
   'gleaming',
   'glow',
   'setting',
   'symbol'],
  'A resplendent peacock, proudly displaying its iridescent plumage in a dazzling fan of colors.': ['its',
   'plumage',
   'fan'],
  'A stealthy tiger prowling through the jungle, its striped coat blending seamlessly with the dappled shadows.': ['tiger',
   'its',
   'coat'],
  'A cunning fox, its fiery fur camouflaged among the vibrant hues of the forest.': ['cunning',
   'its',
   'fiery',
   'fur',
   'camouflaged',
   'hues'],
  'A songbird perched on a blossoming branch, its melodious song filling the air with music and enchantment.': ['songbird',
   'perched',
   'blossoming',
   'its',
   'song',
   'filling',
   'air',
   'music'],
  'A diligent student, surrounded by books and notes, their focused expression a reflection of their thirst for knowledge and growth.': ['diligent',
   'surrounded',
   'books',
   'focused',
   'expression',
   'reflection',
   'thirst',
   'knowledge'],
  'Two lifelong friends, embracing in a warm hug, their laughter and shared memories a testament to the enduring power of friendship.': ['Two',
   'embracing',
   'laughter',
   'shared',
   'memories',
   'testament',
   'enduring',
   'power'],
  'A majestic eagle, soaring high above the mountains, its keen eyes surveying the world below.': ['majestic',
   'soaring',
   'its',
   'eyes',
   'surveying',
   'world'],
  'A lamp on a table, casting a warm and inviting glow, illuminating our paths through the darkness.': ['lamp'],
  'A solitary hedgehog, curled up in a protective ball, a master of self-defense.': ['solitary',
   'curled',
   'master'],
  'A lobster, its armored exoskeleton glistening in the water, a prized catch of the sea.': ['its',
   'glistening',
   'catch'],
  'A diligent bee, tirelessly collecting pollen to sustain its hive, a symbol of industriousness and cooperation.': ['diligent',
   'collecting',
   'pollen',
   'sustain',
   'its',
   'symbol',
   'industriousness'],
  'A luxurious car, meticulously polished to a mirror-like shine, ensconced within a climate-controlled garage adorned with rare vintage car memorabilia.': ['meticulously',
   'garage',
   'adorned',
   'vintage',
   'car'],
  'A refrigerator brimming with fresh ingredients, a source of culinary inspiration and the heart of family gatherings.': ['refrigerator',
   'heart',
   'family'],
  'A vintage clock, its intricate gears and pendulum in perpetual motion, marking the inexorable passage of time with timeless elegance.': ['vintage',
   'its',
   'intricate',
   'gears',
   'pendulum',
   'marking',
   'passage',
   'time'],
  "A camera's lens focused intently on a subject, capturing a singular moment in time for eternity, a testament to the power of photography.": ['lens',
   'focused',
   'capturing',
   'moment',
   'time',
   'testament',
   'power'],
  "A passionate musician, lost in the music, fingers caressing guitar strings, a melody weaving its way through the audience's hearts, kindling emotions.": ['passionate',
   'fingers',
   'guitar',
   'melody',
   'weaving',
   'its',
   'way'],
  "A prolific writer, fingers dancing on a keyboard, weaving words into a tapestry of imagination and emotion, connecting with readers' souls.": ['prolific',
   'fingers',
   'dancing',
   'weaving',
   'words',
   'tapestry',
   'imagination',
   'connecting'],
  'A nimble goat, balancing precariously on a rocky ledge, its surefooted nature a marvel of adaptation.': ['nimble',
   'its',
   'nature',
   'marvel'],
  'A camera lens capturing a breathtaking landscape, freezing a moment of natural beauty in time.': ['camera',
   'lens',
   'capturing',
   'breathtaking',
   'moment',
   'beauty'],
  'A translucent jellyfish, pulsating gently in the depths of the sea, a symbol of otherworldly beauty.': ['translucent',
   'pulsating',
   'depths',
   'symbol'],
  'A phone, its screen aglow with notifications, a lifeline connecting us to the digital world and to each other.': ['its',
   'screen',
   'aglow',
   'lifeline',
   'connecting',
   'world'],
  'A playful pig, gleefully rolling in a mud puddle, its joyful antics a celebration of simple pleasures.': ['playful',
   'rolling',
   'mud',
   'its',
   'joyful',
   'antics',
   'celebration'],
  'A vigilant meerkat, standing on its hind legs, keeping a watchful eye on the African savannah.': ['vigilant',
   'standing',
   'its',
   'hind',
   'keeping',
   'eye',
   'African'],
  'A resourceful raccoon, deftly searching through garbage cans, a symbol of urban adaptation.': ['resourceful',
   'searching',
   'garbage',
   'symbol'],
  'A talented chef meticulously crafting a culinary masterpiece, expertly balancing flavors, textures, and presentation in a symphony for the senses.': ['talented',
   'chef',
   'meticulously',
   'crafting',
   'presentation',
   'symphony'],
  'A chameleon, its skin shifting colors to blend seamlessly with its surroundings, a master of adaptation.': ['its',
   'skin',
   'shifting',
   'colors',
   'blend',
   'its',
   'master'],
  'A firefighter, heroically rescuing a frightened kitten from the heights of a tree, embodying courage, compassion, and community spirit.': ['heroically',
   'rescuing',
   'kitten',
   'heights',
   'embodying',
   'community'],
  'A pen on a desk, poised to transcribe the thoughts and dreams that flow from the mind to the page.': ['pen',
   'transcribe',
   'dreams'],
  'A dedicated scientist, surrounded by complex equipment and colorful solutions, unlocking the secrets of the universe with boundless curiosity.': ['dedicated',
   'surrounded',
   'equipment',
   'unlocking',
   'secrets',
   'universe',
   'boundless'],
  'A masterful chef, orchestrating a culinary symphony in a bustling kitchen, the aromas and flavors weaving an unforgettable dining experience.': ['masterful',
   'orchestrating',
   'symphony',
   'bustling',
   'aromas',
   'flavors',
   'weaving',
   'dining'],
  'A joyful dog, tail wagging enthusiastically, playfully fetching a stick with boundless energy and happiness.': ['joyful',
   'tail',
   'wagging',
   'fetching',
   'stick',
   'boundless',
   'energy'],
  "A massive bear, its fur glistening with the sheen of freshly caught fish, a symbol of nature's grandeur.": ['massive',
   'its',
   'fur',
   'glistening',
   'sheen',
   'caught',
   'symbol'],
  'A playful hamster, running tirelessly on its wheel, a whirlwind of energy in a tiny package.': ['playful',
   'running',
   'its',
   'whirlwind',
   'energy'],
  'A well-worn book, its pages filled with dog-eared corners and hand-scrawled notes, a treasure trove of wisdom and imagination.': ['its',
   'pages',
   'filled',
   'corners',
   'treasure',
   'trove',
   'wisdom'],
  'A nimble rabbit hopping through a meadow, its soft fur and agile movements a testament to the beauty of the natural world.': ['nimble',
   'rabbit',
   'its',
   'fur',
   'agile',
   'movements',
   'testament',
   'beauty'],
  "A sleek shark, effortlessly gliding through the depths of the ocean, a symbol of nature's power and mystery.": ['sleek',
   'gliding',
   'depths',
   'symbol',
   'power'],
  'A wallet, its worn leather exterior bearing the traces of a life well-lived, a repository of memories and aspirations.': ['its',
   'leather',
   'bearing',
   'traces',
   'life',
   'repository',
   'memories'],
  'A sleek fish gliding through a clear pond, its iridescent scales catching the dappled sunlight, a living work of art.': ['sleek',
   'fish',
   'gliding',
   'its',
   'scales',
   'living',
   'work'],
  'A television remote, its buttons a gateway to a world of entertainment and information at our fingertips.': ['television',
   'its',
   'world'],
  "A wallet in a pocket, carrying the essentials of identity and commerce, a silent companion on life's journey.": ['wallet'],
  'A bicycle resting by a scenic trail, an invitation to embark on a journey of exploration and adventure.': ['bicycle',
   'journey',
   'exploration'],
  "A compassionate doctor, her caring hands gently placed on a patient's chest, attentively listening to the rhythmic melody of a beating heart, symbolizing the art of healing.": ['compassionate',
   'caring',
   'hands',
   'placed',
   'listening',
   'melody',
   'symbolizing',
   'art'],
  "A playful dolphin, leaping joyfully from the ocean's depths, a symbol of the sea's boundless wonder.": ['playful',
   'leaping',
   'symbol',
   'boundless'],
  'A striking zebra, its bold black and white stripes a striking contrast against the African savannah.': ['striking',
   'its',
   'stripes',
   'striking',
   'contrast',
   'African'],
  "A vigilant police officer, patrolling the city's streets with unwavering dedication, a shield against chaos, and a beacon of safety.": ['vigilant',
   'police',
   'patrolling',
   'streets',
   'shield',
   'beacon'],
  'A state-of-the-art computer, its processing power humming silently as it seamlessly orchestrates complex tasks in the digital realm.': ['its',
   'processing',
   'power',
   'humming',
   'orchestrates',
   'tasks'],
  'A comfortable chair bathed in the gentle glow of sunlight, inviting relaxation and contemplation by the window.': ['chair',
   'gentle',
   'glow',
   'contemplation'],
  'A resilient penguin, expertly navigating the icy terrain of Antarctica, a symbol of endurance and adaptation.': ['resilient',
   'navigating',
   'icy',
   'terrain',
   'symbol',
   'endurance'],
  'A loyal and energetic dog obediently retrieving a bright red frisbee, showcasing the bond between human and canine.': ['dog'],
  'A dedicated teacher, standing before a classroom filled with eager young minds, shaping the future one lesson at a time.': ['dedicated',
   'standing',
   'classroom',
   'filled',
   'shaping',
   'future',
   'one',
   'lesson'],
  'A wise owl, perched atop a moss-covered branch, its golden eyes shining with ancient knowledge.': ['wise',
   'perched',
   'its',
   'eyes',
   'shining',
   'ancient'],
  'A computer screen alive with lines of code, a digital canvas where ideas come to life through technology.': ['computer',
   'screen',
   'canvas',
   'ideas',
   'come',
   'life'],
  'A majestic horse in full gallop, every sinew of its powerful body working in harmony, an embodiment of grace and strength.': ['majestic',
   'horse',
   'its',
   'working',
   'grace'],
  'A cheetah, the fastest land animal, streaking across the African plains with unmatched speed and grace.': ['fastest',
   'land',
   'streaking',
   'African',
   'plains',
   'speed'],
  'A majestic horse clearing a hurdle with grace and precision, a testament to the trust and partnership between horse and rider.': ['majestic',
   'horse',
   'grace',
   'testament',
   'horse'],
  "A tranquil beach at sunrise, its golden sands kissed by gentle waves under the warm embrace of the sun's first rays, evoking serenity and renewal.": ['beach',
   'its',
   'gentle',
   'embrace'],
  'A vibrant fish darting through crystal-clear waters, vibrant scales catching the dappled sunlight, a testament to the beauty of aquatic life.': ['fish',
   'scales',
   'testament',
   'beauty'],
  'A mirror on the wall, reflecting our ever-changing selves, a witness to our moments of introspection.': ['mirror',
   'moments'],
  "A serene sheep, peacefully grazing in a lush, green field, its woolly coat a symbol of nature's abundance.": ['serene',
   'grazing',
   'its',
   'coat',
   'symbol'],
  'A massive rhinoceros, its horn a symbol of ancient strength, roaming freely in the wild.': ['massive',
   'its',
   'symbol',
   'ancient',
   'roaming'],
  'A graceful and agile cat executing a flawless mid-air pounce onto a tangled ball of yarn, epitomizing feline grace and precision.': ['graceful',
   'agile',
   'cat',
   'ball',
   'grace'],
  'A cutting-edge television, its expansive screen transporting viewers to vividly immersive worlds, where stories come to life.': ['cutting-edge',
   'its',
   'screen',
   'transporting',
   'viewers',
   'stories',
   'come'],
  'A nimble squirrel, expertly navigating the treetops, a symbol of resourcefulness and agility.': ['nimble',
   'navigating',
   'symbol',
   'resourcefulness'],
  'A fearless firefighter, clad in protective gear, fearlessly ascending a towering ladder to rescue a stranded kitten, embodying courage and compassion.': ['fearless',
   'clad',
   'towering',
   'ladder',
   'rescue',
   'embodying',
   'courage'],
  'A graceful octopus, its sinuous tentacles propelling it through the undersea world with grace and precision.': ['graceful',
   'its',
   'sinuous',
   'tentacles',
   'propelling',
   'world',
   'grace'],
  'A delicate butterfly, its wings a kaleidoscope of colors, sipping nectar from a vibrant flower.': ['delicate',
   'its',
   'wings',
   'kaleidoscope',
   'sipping',
   'nectar'],
  'A tranquil turtle basking on a sunlit rock, its ancient wisdom hidden beneath a serene exterior.': ['turtle',
   'its',
   'ancient',
   'wisdom',
   'hidden',
   'serene'],
  "A curious platypus, swimming gracefully in a clear stream, a testament to nature's creativity.": ['curious',
   'swimming',
   'testament'],
  'A majestic lion, its powerful roar reverberating through the savannah, a symbol of strength and majesty.': ['majestic',
   'its',
   'roar',
   'reverberating',
   'symbol',
   'strength'],
  'A compassionate doctor, deeply connected with a patient, their stethoscope a bridge to understanding and healing.': ['compassionate',
   'bridge',
   'understanding'],
  'A graceful deer, its antlers a crown of nobility, pausing in the dappled shade of a forest glade.': ['graceful',
   'its',
   'forest'],
  'A clever parrot, perched on a branch, its vivid feathers matching the brilliance of its speech.': ['clever',
   'perched',
   'its',
   'feathers',
   'matching',
   'brilliance',
   'its'],
  'A clock on the wall, its rhythmic ticking a constant companion in the ebb and flow of our daily lives.': ['clock',
   'its'],
  'A powerful gorilla, its intelligent gaze a window to the mysteries of the jungle.': ['its',
   'gaze',
   'window',
   'mysteries'],
  'A phone, vibrating with incoming messages, an indispensable lifeline connecting people across distances, blurring the boundaries of space.': ['vibrating',
   'lifeline',
   'connecting',
   'people',
   'blurring',
   'boundaries'],
  'A graceful flamingo, standing gracefully in the shallows, its pink plumage a beacon of elegance.': ['graceful',
   'standing',
   'its',
   'plumage',
   'beacon']},
 'C': {'They skate gracefully on the ice rink.': ['skate', 'ice'],
  'They play tag in the park.': ['play'],
  'They swim in the crystal-clear waters of the lake.': ['swim', 'waters'],
  'The elephant sprays itself with water.': ['elephant'],
  'She swings on the playground swing.': ['swings', 'playground'],
  'The firefighter sprays water to put out the fire.': ['firefighter',
   'water'],
  'He flies a kite at the beach.': ['flies', 'kite'],
  'He dances to the rhythm of the music.': ['dances', 'rhythm'],
  'The chef grills juicy steaks on the barbecue.': ['chef'],
  'She hugs her teddy bear tightly.': ['bear'],
  'He rides his bike in the park.': ['rides', 'bike'],
  'He fixes the leaky faucet in the kitchen.': ['fixes', 'faucet'],
  'The tiger prowls through the jungle.': ['tiger'],
  'The shark swims in the deep ocean.': ['shark', 'swims'],
  'They color with crayons on paper.': ['color', 'crayons'],
  'They waddle like penguins at the zoo.': ['waddle', 'penguins'],
  "They climb to the mountain's summit.": ['climb'],
  'The chef prepares a gourmet meal for the guests.': ['chef', 'meal'],
  'She rides a rollercoaster at the theme park.': ['rides',
   'rollercoaster',
   'theme'],
  'The kids love to run around in the park.': ['kids', 'run'],
  'He smiles warmly at everyone he meets.': ['smiles', 'everyone'],
  'He catches the ball with one hand.': ['catches', 'ball', 'one'],
  'The eagle soars high in the sky.': ['eagle'],
  'They build a sandcastle on the beach.': ['build', 'sandcastle'],
  'The chameleon changes color to blend in.': ['chameleon', 'color', 'blend'],
  'The musician plays a melodic tune on the piano.': ['musician', 'tune'],
  'She snuggles with her teddy bear.': ['snuggles'],
  'The koala clings to the eucalyptus tree.': ['koala',
   'clings',
   'eucalyptus'],
  'The cheetah is the fastest land animal.': ['cheetah', 'fastest', 'land'],
  'She blows a kiss to her loved one.': ['blows', 'kiss'],
  'The rhinoceros has a horn on its nose.': ['rhinoceros', 'its'],
  'The bird sings a beautiful song.': ['bird', 'sings'],
  'The teacher wipes the chalkboard clean.': ['teacher'],
  'The teacher teaches the students with passion.': ['teacher'],
  'The seagull soars over the ocean.': ['seagull'],
  'She swims in the ocean on a hot day.': ['swims', 'ocean'],
  'He crawls under the table to hide.': ['table'],
  'She whispers a secret to her best friend.': ['whispers'],
  'The giraffe has a long neck.': ['giraffe'],
  'They paint colorful pictures.': ['paint'],
  'The artist creates intricate sculptures from marble.': ['artist',
   'intricate',
   'sculptures'],
  'They splash in puddles after the rain.': ['splash', 'puddles'],
  'The chicken lays fresh eggs.': ['chicken'],
  'They shout with joy at the surprise party.': ['shout'],
  'He juggles colorful balls in the park.': ['juggles', 'balls'],
  'The owl hoots in the night.': ['owl'],
  'She rides a horse in the countryside.': ['rides', 'horse'],
  'They kick a soccer ball in the park.': ['kick', 'soccer', 'ball'],
  'The fish swims gracefully in the aquarium.': ['fish', 'swims'],
  'He washes his hands before dinner.': ['washes', 'hands'],
  'She feeds the hungry ducks at the pond.': ['feeds', 'ducks'],
  'The platypus is a unique mammal.': ['platypus'],
  'The jellyfish drifts in the water.': ['jellyfish'],
  'They read a captivating story before bedtime.': ['read',
   'captivating',
   'story'],
  'They wave goodbye as the train departs.': ['wave'],
  'The lion is known as the king of the jungle.': ['lion'],
  'She bakes cookies for the holiday season.': ['bakes', 'cookies', 'holiday'],
  'She rides her bike through the scenic countryside.': ['rides', 'bike'],
  'The dolphin leaps out of the water.': ['dolphin'],
  'He watches the stars twinkle at night.': ['watches', 'stars', 'twinkle'],
  'The butterfly flutters among flowers.': ['butterfly'],
  'The elephant is the largest land animal.': ['elephant', 'land'],
  'The kangaroo has powerful hind legs.': ['kangaroo', 'hind'],
  'He exercises at the gym regularly.': ['gym'],
  'He eats a delicious slice of pizza.': ['eats', 'slice'],
  'The squirrel collects acorns in the park.': ['squirrel'],
  'He rolls the dice for a board game.': ['rolls', 'dice', 'board'],
  'She watches the sunrise from her balcony.': ['watches', 'sunrise'],
  'She wears a red dress to the party.': ['wears', 'dress'],
  'He cooks a delicious meal for his family.': ['cooks', 'meal'],
  'The mouse nibbles on a piece of cheese.': ['mouse'],
  'She throws the ball to her friend.': ['throws', 'ball'],
  'He cuts a slice of birthday cake.': ['cuts', 'slice', 'birthday'],
  'The dog barked loudly in the yard.': ['dog'],
  'She catches a butterfly in her hand.': ['catches', 'butterfly'],
  'She winks playfully at her friend.': ['winks'],
  'The parrot can mimic human speech.': ['parrot'],
  'The chef cooks a tasty meal.': ['chef', 'cooks'],
  'He marches proudly in the parade.': ['marches'],
  'She bakes a batch of chocolate chip cookies.': ['bakes', 'chocolate'],
  'They chop vegetables for a salad.': ['chop', 'vegetables'],
  'He dances with elegance at the ball.': ['dances', 'elegance'],
  'The pig rolls in the mud.': ['pig', 'rolls'],
  'The bear hibernates during the winter.': ['bear'],
  'The zebra has black and white stripes.': ['zebra'],
  'They bark loudly when the doorbell rings.': ['bark', 'doorbell'],
  'They wave to their friends across the street.': ['wave', 'friends'],
  'He fixes a broken bicycle.': ['fixes'],
  'The kitten pounces on a toy mouse.': ['kitten', 'pounces', 'toy'],
  'The goat climbs the rocky hill.': ['goat'],
  'They run races at the school sports day.': ['run', 'school'],
  'They swim in the pool on hot summer days.': ['swim', 'pool'],
  'The peacock displays its colorful feathers.': ['peacock', 'its'],
  'The cow grazes in the pasture.': ['cow'],
  'The lobster has claws for defense.': ['lobster'],
  'He can jump over the small fence.': ['jump'],
  'The gorilla is a strong and intelligent ape.': ['gorilla'],
  'She hops on one foot during the game.': ['hops', 'one', 'foot'],
  'The penguin waddles on ice.': ['penguin'],
  'He snaps a photo of the beautiful sunset.': ['snaps', 'photo'],
  'She paints a beautiful landscape with vibrant colors.': ['paints',
   'landscape'],
  'She slides down the snowy hill on a sled.': ['slides', 'snowy', 'hill'],
  'The bird sings a sweet melody.': ['bird', 'sings'],
  'The athlete jumps over the high bar with grace.': ['athlete', 'bar'],
  'The sun shines through the clouds.': ['sun', 'shines'],
  'The baby laughs at funny faces.': ['baby', 'laughs'],
  'The scientist observes the behavior of ants.': ['scientist', 'behavior'],
  'The horse galloped across the field.': ['horse'],
  'The turtle has a hard shell.': ['turtle'],
  "The mechanic fixes the car's engine.": ['mechanic', 'fixes'],
  'She whispers a secret to her friend.': ['whispers'],
  'The car honks loudly in traffic.': ['car'],
  'They draw colorful pictures on the sidewalk.': ['draw', 'pictures'],
  'The crocodile lurks in the water.': ['crocodile'],
  'The baby giggles when tickled.': ['baby', 'giggles'],
  'They float on inflatable rafts in the pool.': ['float', 'rafts'],
  'The baker mixes the batter for cupcakes.': ['baker', 'mixes', 'batter'],
  'The sun shines brightly in the sky.': ['sun', 'shines'],
  'She reads a bedtime story to her child.': ['reads', 'story'],
  'The artist sketches a beautiful landscape.': ['artist'],
  'He builds a sandcastle on the beach.': ['builds', 'sandcastle'],
  'They blow out the birthday candles.': ['blow', 'birthday'],
  'He dives into the pool with a splash.': ['dives', 'pool'],
  'The butterfly flits from flower to flower.': ['butterfly', 'flower'],
  'He drives his car to work every day.': ['car', 'work'],
  'She hides behind the curtains.': ['hides'],
  'She holds a bouquet of flowers.': ['holds', 'bouquet'],
  'They watch movies on Friday nights.': ['watch', 'movies'],
  'The waiter serves delicious meals to the customers.': ['waiter',
   'serves',
   'meals'],
  'The spider spins a delicate web.': ['spider', 'delicate'],
  'The cat pounces on a toy mouse.': ['cat', 'pounces', 'toy'],
  'The cat sleeps all day in the sun.': ['cat', 'day'],
  'They watch a funny cartoon on TV.': ['watch'],
  'The raccoon rummages through the trash.': ['raccoon'],
  'The octopus has tentacles.': ['octopus'],
  'They plant tulip bulbs in the garden.': ['plant', 'tulip', 'bulbs'],
  'The fox has a bushy tail.': ['fox'],
  'They skip rope in the playground.': ['skip', 'rope'],
  'The owl hunts for prey at night.': ['owl'],
  'She wraps a gift with colorful paper.': ['wraps', 'gift'],
  'He whistles a catchy tune.': ['whistles', 'catchy'],
  'The rabbit hops around the garden.': ['rabbit', 'hops'],
  'She swings back and forth in the park.': ['swings', 'forth'],
  'The flamingo stands on one leg.': ['flamingo', 'one'],
  'He barks loudly at passing cars.': ['barks', 'passing'],
  'He dives into the deep end of the pool.': ['dives', 'end'],
  'She always eats breakfast before going to school.': ['eats',
   'breakfast',
   'going'],
  'He listens to soothing music to relax.': ['listens', 'soothing', 'music'],
  'The bee buzzes around the garden.': ['bee'],
  'The baby cries for attention.': ['baby', 'cries'],
  'The snake slithers through the grass.': ['snake'],
  'The bees buzz around the hive.': ['bees', 'buzz'],
  'The deer gracefully leaps through the forest.': ['deer'],
  'She combs her hair in front of the mirror.': ['combs', 'hair', 'front'],
  'They climb the steep mountain.': ['climb'],
  'The dog fetches a stick in the yard.': ['dog', 'stick'],
  'She writes in her journal every night.': ['writes', 'journal'],
  'He bounces a basketball on the court.': ['bounces', 'basketball'],
  'The sheep provides wool for clothing.': ['sheep'],
  'She plants flowers in her garden every spring.': ['plants',
   'flowers',
   'garden'],
  'They climb a tree in the forest.': ['climb', 'tree'],
  'They jump in puddles after the rain.': ['jump', 'puddles'],
  'A television remote.': ['television'],
  'A lobster in a tank.': ['lobster'],
  'A musician singing a song.': ['musician'],
  'A platypus in a stream.': ['platypus'],
  'A table with dishes.': ['table'],
  'A rabbit hopping.': ['rabbit'],
  'A jellyfish in the ocean.': ['jellyfish'],
  'A zebra with stripes.': ['zebra'],
  'A musician playing a guitar.': ['musician'],
  'A chair by the window.': ['chair'],
  'A dog running.': ['dog'],
  'A parrot talking.': ['parrot'],
  'A writer typing a story.': ['writer'],
  'A gorilla in the jungle.': ['gorilla'],
  'A bird perched on a branch.': ['bird', 'perched'],
  'A snake slithering.': ['snake'],
  'A giraffe eating leaves.': ['giraffe'],
  'An athlete running.': ['athlete'],
  'A friend giving a hug.': ['friend', 'hug.'],
  'A clock on the wall.': ['clock'],
  'A teacher in a classroom.': ['teacher'],
  'A firefighter holding a hose.': ['firefighter'],
  'A bear in the woods.': ['bear'],
  'A wallet in a pocket.': ['wallet'],
  'A raccoon searching for food.': ['raccoon', 'searching'],
  'A car driving.': ['car'],
  'A refrigerator with food.': ['refrigerator'],
  'An octopus underwater.': ['octopus'],
  'A porcupine with quills.': ['porcupine'],
  'A peacock displaying its feathers.': ['peacock', 'its'],
  'A horse galloping.': ['horse'],
  'A spider spinning a web.': ['spider'],
  'A beach with waves.': ['beach'],
  'A camera taking a picture.': ['camera'],
  'An owl in a tree.': ['owl'],
  'A cheetah running fast.': ['cheetah', 'running'],
  'A television showing a movie.': ['television'],
  'A scientist conducting an experiment.': ['scientist'],
  'A horse in a stable.': ['horse'],
  'A squirrel on a tree.': ['squirrel'],
  'A doctor listening to a heartbeat.': ['doctor', 'listening'],
  'A school with children.': ['school'],
  'A hedgehog curled up.': ['hedgehog', 'curled'],
  'A phone on a charger.': ['phone'],
  'A camera lens.': ['camera'],
  'A rhinoceros in the wild.': ['rhinoceros'],
  'A pen on a desk.': ['pen'],
  'A lamp on a table.': ['lamp'],
  'A crocodile in a swamp.': ['crocodile'],
  'A mechanic fixing a car.': ['mechanic'],
  'A cat chasing a mouse.': ['cat'],
  'A penguin on ice.': ['penguin'],
  'A book on a shelf.': ['book'],
  'A dog wagging its tail.': ['dog', 'wagging', 'its'],
  'A bird flying.': ['bird'],
  'A book on a table.': ['book'],
  'A police officer patrolling.': ['police', 'officer'],
  'A chameleon changing colors.': ['chameleon'],
  'An artist painting a picture.': ['artist', 'painting'],
  'A meerkat standing alert.': ['meerkat', 'standing'],
  'A tiger prowling.': ['tiger'],
  'A bee buzzing.': ['bee'],
  'A chair at a desk.': ['chair'],
  'A flamingo standing in water.': ['flamingo', 'standing'],
  'A fish swimming.': ['fish'],
  'A doctor with a stethoscope.': ['doctor'],
  'An astronaut floating in space.': ['astronaut', 'floating'],
  'A mirror on the wall.': ['mirror'],
  'A sheep in a field.': ['sheep'],
  'A turtle in a pond.': ['turtle'],
  'A chef cooking.': ['chef'],
  'An umbrella in the rain.': ['umbrella'],
  'An eagle soaring.': ['eagle'],
  'A cow grazing.': ['cow'],
  'A chef preparing a meal.': ['chef'],
  'A firefighter rescuing a cat from a tree.': ['firefighter',
   'rescuing',
   'cat'],
  'A shark in the ocean.': ['shark'],
  'A library full of books.': ['library'],
  'A butterfly on a flower.': ['butterfly'],
  'A phone ringing.': ['phone'],
  'A fish in a pond.': ['fish'],
  'A lion roaring.': ['lion'],
  'A kangaroo jumping.': ['kangaroo'],
  'A cat sleeping.': ['cat'],
  'A chicken in a coop.': ['chicken'],
  'A hamster running on a wheel.': ['hamster', 'running'],
  'A student studying.': ['student'],
  'A refrigerator door.': ['refrigerator'],
  'A deer in the forest.': ['deer'],
  'A computer on a desk.': ['computer'],
  'A computer screen.': ['computer'],
  'A dolphin swimming.': ['dolphin'],
  'A pig in the mud.': ['pig'],
  'A fox in the woods.': ['fox'],
  'A goat climbing.': ['goat'],
  'A wallet on a table.': ['wallet'],
  'A bicycle in a park.': ['bicycle'],
  'A car parked outside.': ['car'],
  'A clock ticking.': ['clock'],
  'A seagull by the sea.': ['seagull']},
 'S': {'The spy likes to eavesdrop on secret conversations.': ['eavesdrop'],
  'The detective carefully scrutinizes the crime scene.': ['detective',
   'scrutinizes'],
  'The investigator interrogates the suspect.': ['investigator',
   'interrogates'],
  'He computes intricate algorithms for computer graphics.': ['computes',
   'intricate',
   'algorithms',
   'computer'],
  'The biochemist will purify the DNA sample for analysis.': ['purify', 'DNA'],
  'He conducted a comprehensive longitudinal psychological study.': ['conducted'],
  'He patents innovative inventions.': ['patents', 'innovative'],
  'The photographer will oversee the entire photoshoot.': ['photographer',
   'oversee'],
  'She produced critically acclaimed films.': ['produced', 'acclaimed'],
  'The surgeon must manipulate delicate tissues during the operation.': ['surgeon',
   'manipulate',
   'delicate',
   'tissues'],
  'He impels his team to achieve greatness.': ['impels', 'team', 'achieve'],
  'The explorer decided to meander through the dense jungle.': ['explorer',
   'meander'],
  'He extrapolates data to make predictions.': ['extrapolates',
   'data',
   'make'],
  'They oversee the construction project with great care.': ['oversee',
   'project'],
  'The diplomats discourse on international relations.': ['discourse'],
  'She secured numerous patents for revolutionary inventions.': ['secured',
   'patents'],
  'The acrobat executed a perfect somersault in mid-air.': ['acrobat',
   'somersault'],
  'The renowned artist sculpted breathtaking masterpieces from rare materials.': ['renowned',
   'artist',
   'breathtaking'],
  'She devises innovative solutions for complex problems.': ['devises',
   'innovative',
   'solutions'],
  'He patents groundbreaking inventions.': ['patents', 'groundbreaking'],
  'He founded transformative humanitarian missions.': ['founded',
   'humanitarian'],
  'The submarine will submerge into the deep ocean waters.': ['submerge',
   'ocean'],
  'They forecast economic trends for the financial market.': ['forecast',
   'trends'],
  'He extrapolates data to make informed predictions.': ['extrapolates',
   'data',
   'make'],
  'The director assembles a diverse cast for the film.': ['director',
   'diverse'],
  'They caress the delicate petals of the rare flower.': ['caress',
   'delicate'],
  'The wanderer yearns to explore uncharted territories.': ['wanderer',
   'yearns',
   'explore'],
  'They forecast market trends for the business.': ['forecast',
   'market',
   'trends'],
  'He revolutionized scientific research with groundbreaking discoveries.': ['revolutionized',
   'research',
   'groundbreaking'],
  'She reclines on the luxurious chaise lounge.': ['reclines', 'chaise'],
  'The conductor composes a symphony for the orchestra.': ['conductor',
   'composes',
   'symphony'],
  'After a long day, she seeks to repose in her favorite chair.': ['repose'],
  'They explore uncharted territories in search of treasure.': ['explore',
   'territories',
   'search'],
  'She composes a sonata for piano and violin.': ['composes',
   'sonata',
   'piano'],
  'The engineer aims to propel the rocket into space.': ['engineer',
   'aims',
   'propel'],
  'She dissects complex issues to understand them better.': ['dissects',
   'issues',
   'understand'],
  'They analyze geological formations in the wilderness.': ['analyze',
   'formations'],
  'The geologist analyzes rock formations in the field.': ['geologist',
   'analyzes',
   'rock',
   'formations'],
  'They propose groundbreaking scientific theories.': ['propose',
   'groundbreaking'],
  'They linger in the art gallery, admiring the masterpieces.': ['linger',
   'art'],
  'The scientist will meticulously analyze the complex data.': ['scientist',
   'meticulously',
   'analyze'],
  'The explorer loves to wander through remote wilderness areas.': ['explorer',
   'wander',
   'remote'],
  'They synthesize new chemical compounds for experimentation.': ['synthesize',
   'chemical',
   'compounds'],
  'The group bursts into spontaneous guffaws at the comedy show.': ['group',
   'bursts',
   'guffaws',
   'comedy'],
  'She computes complex algorithms for artificial intelligence.': ['computes',
   'algorithms'],
  'They navigated intricate international legal frameworks.': ['navigated',
   'intricate'],
  'The attorney litigated a landmark constitutional case.': ['attorney',
   'litigated'],
  'The astronomer aims to observe distant galaxies.': ['astronomer',
   'aims',
   'observe'],
  'They negotiated international peace agreements.': ['negotiated', 'peace'],
  'She sometimes laments the loss of her loved ones.': ['sometimes',
   'laments',
   'loss'],
  'She synchronizes her movements with the music.': ['synchronizes',
   'movements'],
  'They osculate in the moonlight, lost in their love.': ['osculate'],
  'The ballerina executes a flawless pirouette on her toes.': ['pirouette'],
  'He engineered cutting-edge green energy solutions.': ['engineered',
   'cutting-edge',
   'energy'],
  'He optimized supply chain logistics to enhance efficiency.': ['optimized',
   'supply',
   'chain',
   'logistics',
   'enhance'],
  'The conductor orchestrates a symphony performance.': ['conductor',
   'orchestrates',
   'symphony'],
  'She orchestrates a grand musical performance.': ['orchestrates'],
  'She interpreted ancient manuscripts to unlock historical mysteries.': ['interpreted',
   'ancient',
   'manuscripts',
   'unlock'],
  'She coordinated disaster relief efforts.': ['coordinated',
   'disaster',
   'relief'],
  'They construct elaborate mathematical proofs.': ['construct'],
  'The architect designs sustainable buildings.': ['architect', 'designs'],
  'They surveil the area with hidden cameras.': ['surveil', 'hidden'],
  'She calculates the trajectory of the spacecraft.': ['calculates',
   'trajectory'],
  'The innovative engineer pioneered autonomous humanoid robots.': ['innovative',
   'engineer'],
  'He corroborates his research findings with additional data.': ['corroborates',
   'research',
   'findings'],
  'He hauls the heavy load with determination.': ['hauls', 'load'],
  'He engineered a groundbreaking AI algorithm.': ['engineered',
   'groundbreaking',
   'AI'],
  'He constructs mathematical models to solve problems.': ['constructs',
   'models',
   'solve'],
  'The chemist needs to seethe the solution at a specific temperature.': ['seethe'],
  'The detective will intercept the secret message.': ['detective',
   'intercept'],
  'They administered a massive nationwide vaccination initiative.': ['administered',
   'massive',
   'vaccination'],
  'The skilled surgeon performed a life-saving procedure.': ['skilled',
   'surgeon',
   'performed'],
  'She sculpts intricate figurines from clay.': ['sculpts',
   'intricate',
   'figurines'],
  'They synthesized a novel pharmaceutical compound.': ['synthesized',
   'novel'],
  'The scientist will analyze the DNA samples for genetic markers.': ['scientist',
   'analyze',
   'DNA'],
  'She cavorts with the dolphins in the crystal-clear water.': ['cavorts',
   'dolphins'],
  'They fabricated exquisite jewelry pieces.': ['fabricated', 'jewelry'],
  'She pirouettes gracefully in her ballet performance.': ['pirouettes',
   'ballet'],
  'The scientist will analyze the chemical composition of the substance.': ['scientist',
   'analyze',
   'chemical'],
  'The couple osculates passionately in the moonlight.': ['couple',
   'osculates'],
  'The dancers cavort gracefully on the grand stage.': ['cavort'],
  'He orchestrated a peace summit between nations.': ['orchestrated',
   'peace',
   'summit'],
  'The seasoned CEO oversaw global operations.': ['CEO', 'oversaw'],
  'The artist impels the audience to ponder the meaning of his painting.': ['artist',
   'impels',
   'audience'],
  'The journalist aims to document the historical event.': ['journalist',
   'aims',
   'document'],
  'She devised marketing campaigns for global brands.': ['devised',
   'marketing',
   'campaigns'],
  'The detective interrogates the key witnesses.': ['detective',
   'interrogates',
   'key'],
  'They conceptualize innovative ideas for their startup.': ['conceptualize',
   'innovative',
   'ideas'],
  'She sculptures clay into intricate figurines.': ['sculptures',
   'clay',
   'intricate'],
  'During the earthquake, the building began to tumble down.': ['building',
   'tumble'],
  'She dissects intricate legal arguments in the courtroom.': ['dissects',
   'intricate',
   'arguments'],
  'They synthesize chemical compounds for research.': ['synthesize',
   'chemical',
   'compounds'],
  'During the storm, the ship began to surge on the turbulent seas.': ['ship',
   'surge'],
  'She negotiated a multimillion-dollar merger successfully.': ['negotiated',
   'merger'],
  'The playwright crafts compelling dialogues for the play.': ['crafts',
   'compelling',
   'dialogues'],
  'During the hurricane, the ship began to surge in the tumultuous sea.': ['ship',
   'surge'],
  'The tugboat will haul the cargo ship into the harbor.': ['haul', 'ship'],
  'She theorizes about the behavior of subatomic particles.': ['theorizes',
   'behavior'],
  'The scientists propose a revolutionary hypothesis.': ['scientists',
   'propose'],
  'She implemented an advanced healthcare infrastructure overhaul.': ['implemented',
   'healthcare',
   'infrastructure'],
  'He sculpts intricate sculptures from marble.': ['sculpts',
   'intricate',
   'sculptures'],
  'She devises a new strategy for the company.': ['devises', 'strategy'],
  'He unfastens the lock to explore the mysterious room.': ['unfastens',
   'lock',
   'explore'],
  'They analyzed complex financial derivatives and market trends for high-stakes investments.': ['analyzed',
   'derivatives',
   'market',
   'trends'],
  'They explore uncharted territories in search of scientific discovery.': ['explore',
   'territories',
   'search'],
  'He scrutinizes the intricate details of the ancient manuscript.': ['scrutinizes',
   'intricate',
   'details',
   'ancient'],
  'She scrutinizes every aspect of the business plan.': ['scrutinizes',
   'aspect',
   'business'],
  'He synchronizes the choreography with the music.': ['synchronizes',
   'choreography'],
  'The scientist will analyze the intricate chemical reactions.': ['scientist',
   'analyze',
   'intricate',
   'chemical'],
  'He theorizes about the nature of the universe.': ['theorizes', 'nature'],
  'The director assembles an ensemble cast for the film.': ['director'],
  'She plans to scrutinize the financial reports closely.': ['scrutinize'],
  'They fabricate intricate jewelry designs.': ['fabricate',
   'intricate',
   'jewelry'],
  'The visionary architect conceptualized eco-friendly skyscrapers.': ['visionary',
   'architect'],
  'They conducted groundbreaking research in regenerative medicine.': ['conducted',
   'groundbreaking',
   'research'],
  'The diver will immerse into the deep abyss of the ocean.': ['immerse',
   'abyss'],
  'The mourners lament the passing of a great leader.': ['lament', 'passing'],
  'She oversees the entire project with great precision.': ['oversees',
   'project'],
  'He cackles with delight at the humorous story.': ['cackles', 'delight'],
  'He corroborates his findings with extensive research.': ['corroborates',
   'findings'],
  'The accomplished scientist discovered unknown species.': ['scientist'],
  'She supervised multinational corporate conglomerates.': ['supervised'],
  'She purifies the water to make it safe to drink.': ['purifies',
   'water',
   'make'],
  'The chef aims to decontaminate the kitchen before cooking.': ['chef',
   'aims',
   'decontaminate',
   'kitchen'],
  'The research team will scrutinize the findings meticulously.': ['research',
   'team',
   'scrutinize',
   'findings'],
  'The writer crafts compelling narratives for novels.': ['writer',
   'crafts',
   'compelling'],
  'A masterful painter, creating a canvas that captures the essence of the human experience.': ['masterful',
   'creating',
   'canvas',
   'captures',
   'essence'],
  'A brilliant geneticist, unlocking the mysteries of DNA and its role in heredity and disease.': ['brilliant',
   'unlocking',
   'mysteries',
   'DNA',
   'its',
   'role',
   'heredity'],
  'A wise philosopher, contemplating the profound questions of existence and the nature of reality.': ['wise',
   'contemplating',
   'questions',
   'existence',
   'nature'],
  'A renowned physicist, advancing our understanding of the cosmos through groundbreaking discoveries.': ['renowned',
   'advancing',
   'understanding',
   'cosmos',
   'groundbreaking'],
  'A visionary inventor, creating groundbreaking technologies that revolutionize industries.': ['visionary',
   'creating',
   'groundbreaking',
   'technologies',
   'revolutionize'],
  'A visionary renewable energy engineer, designing innovative solutions for a sustainable world.': ['visionary',
   'energy',
   'designing',
   'innovative',
   'solutions'],
  'A dedicated astronaut, embarking on a journey to explore the mysteries of the cosmos.': ['dedicated',
   'embarking',
   'journey',
   'explore',
   'mysteries'],
  'A dedicated humanitarian, working tirelessly to alleviate suffering and promote equality.': ['dedicated',
   'working',
   'alleviate',
   'suffering',
   'promote'],
  "A passionate environmentalist, advocating for the preservation of our planet's natural wonders.": ['passionate',
   'advocating',
   'preservation'],
  "A passionate environmental activist, leading movements to protect our planet's fragile ecosystems.": ['passionate',
   'leading',
   'movements',
   'protect'],
  'An experienced detective meticulously piecing together clues at a crime scene, unraveling a complex mystery.': ['experienced',
   'detective',
   'meticulously',
   'clues',
   'unraveling'],
  'A visionary urban planner, designing sustainable cities that prioritize the well-being of residents.': ['visionary',
   'designing',
   'cities',
   'prioritize',
   'well-being'],
  'A dedicated archaeologist, uncovering the secrets of ancient civilizations buried beneath the earth.': ['dedicated',
   'uncovering',
   'secrets',
   'ancient',
   'civilizations',
   'buried'],
  'A diligent scientist, conducting groundbreaking experiments that push the boundaries of human knowledge.': ['diligent',
   'groundbreaking',
   'experiments',
   'push',
   'boundaries'],
  'A dedicated entomologist, studying the intricate world of insects and their vital role in ecosystems.': ['dedicated',
   'studying',
   'intricate',
   'world',
   'insects',
   'role'],
  'A compassionate humanitarian worker, delivering aid to communities affected by natural disasters and crises.': ['compassionate',
   'humanitarian',
   'delivering',
   'aid',
   'communities',
   'affected',
   'disasters'],
  'A fearless war correspondent, reporting from conflict zones to shed light on the realities of war.': ['fearless',
   'war',
   'reporting',
   'conflict',
   'zones',
   'shed',
   'light',
   'realities'],
  "A dedicated paleontologist, uncovering the fossilized remains of ancient creatures from Earth's distant past.": ['dedicated',
   'uncovering',
   'remains',
   'ancient',
   'creatures'],
  'A dedicated linguist, deciphering ancient scripts and preserving endangered languages.': ['dedicated',
   'deciphering',
   'ancient',
   'scripts',
   'preserving',
   'endangered'],
  'A passionate botanist, exploring diverse ecosystems and discovering new plant species.': ['passionate',
   'exploring',
   'diverse',
   'ecosystems',
   'discovering',
   'plant'],
  'A brilliant astronomer, peering through powerful telescopes to unlock the secrets of the cosmos.': ['brilliant',
   'peering',
   'telescopes',
   'unlock',
   'secrets'],
  'A compassionate nurse, providing comfort and care to patients in their most vulnerable moments.': ['compassionate',
   'providing',
   'comfort',
   'care',
   'patients'],
  'A compassionate social worker, providing support to individuals and families facing adversity.': ['compassionate',
   'providing',
   'support',
   'individuals',
   'families',
   'facing'],
  'A compassionate social worker, advocating for marginalized communities and social justice.': ['compassionate',
   'advocating',
   'communities'],
  'A compassionate pediatrician, caring for the health and well-being of young patients.': ['compassionate',
   'caring',
   'health',
   'well-being'],
  'A fearless test pilot, pushing the limits of aviation in experimental aircraft.': ['fearless',
   'test',
   'pushing',
   'limits',
   'aviation'],
  'A masterful blacksmith, forging intricate metalwork that blends artistry and functionality.': ['masterful',
   'forging',
   'intricate',
   'metalwork',
   'blends',
   'artistry'],
  'A skilled surgeon, performing a life-saving operation with steady hands and unwavering focus.': ['skilled',
   'performing',
   'operation',
   'hands'],
  'A fearless mountain climber, ascending to breathtaking heights with unwavering determination.': ['fearless',
   'mountain',
   'breathtaking',
   'heights'],
  'A passionate humanitarian activist, advocating for the rights and dignity of all people.': ['passionate',
   'humanitarian',
   'advocating',
   'rights',
   'dignity'],
  "A fearless storm chaser, documenting the fury and beauty of nature's most powerful weather phenomena.": ['fearless',
   'storm',
   'documenting',
   'fury',
   'beauty',
   'weather'],
  'A masterful calligrapher, creating intricate and beautiful scripts with expert brushwork.': ['masterful',
   'creating',
   'intricate',
   'scripts'],
  'A talented glassblower, shaping molten glass into exquisite works of art.': ['talented',
   'shaping',
   'glass',
   'works'],
  'A courageous emergency medical responder, providing critical care in high-pressure situations.': ['courageous',
   'emergency',
   'providing',
   'care'],
  "A vigilant lifeguard, scanning the waters with unwavering attention, ensuring swimmers' safety.": ['vigilant',
   'scanning',
   'waters',
   'ensuring'],
  'A dedicated archaeologist, excavating ancient ruins to uncover clues about past civilizations.': ['dedicated',
   'excavating',
   'ancient',
   'ruins',
   'uncover',
   'clues',
   'past'],
  'A masterful glassblower, shaping intricate and delicate glass creations with precision.': ['masterful',
   'shaping',
   'intricate',
   'delicate',
   'glass',
   'creations'],
  'A brilliant computer scientist, pioneering advancements in artificial intelligence and machine learning.': ['brilliant',
   'computer',
   'intelligence'],
  'A resourceful secretary, efficiently managing a bustling office, a linchpin of organization and communication.': ['resourceful',
   'managing',
   'bustling',
   'linchpin',
   'organization'],
  'A masterful sculptor, chiseling a work of art that reveals the soul within the stone.': ['masterful',
   'chiseling',
   'work',
   'art',
   'reveals',
   'soul'],
  'A brilliant physicist, unraveling the mysteries of the universe through groundbreaking research.': ['brilliant',
   'unraveling',
   'mysteries',
   'universe',
   'groundbreaking'],
  'A compassionate counselor, providing guidance and support to individuals facing personal challenges.': ['compassionate',
   'providing',
   'guidance',
   'support',
   'individuals',
   'facing'],
  'A masterful dancer, moving with grace and precision in a mesmerizing performance.': ['masterful',
   'moving',
   'grace',
   'precision'],
  'A brilliant mathematician, unraveling complex equations with elegance and precision.': ['brilliant',
   'unraveling',
   'equations',
   'elegance'],
  'A fearless journalist, reporting from the frontlines of global events, seeking truth in the face of danger.': ['fearless',
   'reporting',
   'frontlines',
   'seeking',
   'truth',
   'face'],
  'A dedicated teacher, inspiring the next generation with innovative and engaging lessons.': ['dedicated',
   'inspiring',
   'generation',
   'innovative'],
  'A masterful conductor, leading an orchestra in a performance that moves the soul.': ['masterful',
   'leading',
   'orchestra',
   'performance',
   'moves'],
  'A talented fashion designer, creating clothing that expresses individuality and style.': ['talented',
   'fashion',
   'creating',
   'clothing',
   'expresses',
   'individuality'],
  'A brilliant economist, analyzing complex financial systems and their impact on society.': ['brilliant',
   'analyzing',
   'systems',
   'impact'],
  'A visionary entrepreneur, building a successful business empire from the ground up.': ['visionary',
   'building',
   'business',
   'empire',
   'ground'],
  'A talented choreographer, crafting mesmerizing dance routines that convey stories and emotions.': ['talented',
   'crafting',
   'dance',
   'routines',
   'stories'],
  'A skilled gardener, tending to a vibrant tapestry of blooms and foliage, creating a botanical paradise.': ['skilled',
   'tending',
   'tapestry',
   'blooms',
   'creating'],
  'A skilled photographer, capturing moments of beauty and truth that resonate with viewers.': ['skilled',
   'capturing',
   'moments',
   'beauty',
   'truth',
   'resonate'],
  'A skilled architect, envisioning and designing awe-inspiring structures that redefine city skylines.': ['skilled',
   'designing',
   'structures',
   'city'],
  'A courageous peacekeeper, working in conflict zones to promote understanding and reconciliation.': ['courageous',
   'working',
   'conflict',
   'zones',
   'promote',
   'understanding'],
  'A dedicated wildlife conservationist, working to protect endangered species and their habitats.': ['dedicated',
   'wildlife',
   'working',
   'protect',
   'endangered',
   'species'],
  'A compassionate therapist, providing guidance and support to individuals on their journey to mental well-being.': ['compassionate',
   'providing',
   'guidance',
   'support',
   'individuals',
   'journey'],
  'An agile acrobat, defying gravity with breathtaking feats of strength and balance.': ['agile',
   'defying',
   'gravity',
   'breathtaking',
   'feats',
   'strength'],
  'A talented composer, crafting music that resonates with the human soul and stirs deep emotions.': ['talented',
   'crafting',
   'music',
   'resonates',
   'soul',
   'stirs'],
  "A passionate wildlife photographer, capturing the majesty and vulnerability of Earth's creatures.": ['passionate',
   'wildlife',
   'capturing',
   'majesty',
   'vulnerability'],
  "A fearless deep-sea explorer, venturing into the ocean's abyss to discover new life forms.": ['fearless',
   'deep-sea',
   'venturing',
   'abyss',
   'discover',
   'life'],
  'A dedicated librarian, surrounded by ancient tomes and manuscripts, preserving knowledge for future generations.': ['dedicated',
   'surrounded',
   'ancient',
   'tomes',
   'preserving',
   'knowledge',
   'future'],
  'An innovative software developer, creating cutting-edge applications that shape the digital landscape.': ['innovative',
   'software',
   'creating',
   'cutting-edge',
   'applications',
   'shape'],
  'An agile gymnast, performing gravity-defying routines that inspire awe and admiration.': ['agile',
   'performing',
   'routines',
   'inspire',
   'awe'],
  'A talented musician, composing a symphony that resonates with the deepest emotions of the audience.': ['talented',
   'composing',
   'symphony',
   'resonates',
   'emotions'],
  'A talented poet, weaving words into verses that evoke deep emotions and contemplation.': ['talented',
   'weaving',
   'words',
   'verses',
   'evoke',
   'emotions'],
  'A visionary space explorer, embarking on missions to distant planets in search of extraterrestrial life.': ['visionary',
   'space',
   'embarking',
   'missions',
   'planets',
   'search'],
  'A brilliant nanotechnologist, working at the cutting edge of science to engineer the future.': ['brilliant',
   'working',
   'engineer'],
  'A compassionate hospice worker, providing comfort and support to individuals in their final moments.': ['compassionate',
   'hospice',
   'providing',
   'comfort',
   'support',
   'individuals'],
  'A masterful chef, orchestrating a multi-course gastronomic extravaganza, each dish a masterpiece of flavor and presentation.': ['masterful',
   'orchestrating',
   'dish',
   'masterpiece',
   'flavor'],
  'An experienced pilot, guiding a plane through turbulent skies with calm expertise.': ['experienced',
   'guiding',
   'plane',
   'skies'],
  'A daring explorer, trekking through uncharted territories in search of hidden wonders.': ['daring',
   'trekking',
   'territories',
   'search',
   'hidden'],
  'A fearless firefighter, rushing into the heart of danger to save lives and protect communities.': ['fearless',
   'rushing',
   'heart',
   'danger',
   'save',
   'lives',
   'protect'],
  'A compassionate animal rights advocate, working to protect the welfare of all living beings.': ['compassionate',
   'animal',
   'rights',
   'working',
   'protect',
   'welfare',
   'living'],
  'A wise judge, presiding over a courtroom with impartiality and a commitment to justice.': ['wise',
   'presiding',
   'courtroom',
   'impartiality',
   'commitment'],
  'A courageous search and rescue worker, risking their life to save others in perilous situations.': ['courageous',
   'search',
   'rescue',
   'risking',
   'life',
   'save',
   'others'],
  'A renowned author, crafting a novel that captivates readers and sparks profound introspection.': ['renowned',
   'crafting',
   'novel',
   'captivates',
   'readers',
   'sparks'],
  'A brilliant quantum physicist, exploring the mind-bending realm of subatomic particles.': ['brilliant',
   'quantum',
   'exploring',
   'realm'],
  'A visionary architect, designing sustainable and inspiring structures that harmonize with nature.': ['visionary',
   'designing',
   'inspiring',
   'structures',
   'harmonize'],
  'A charismatic politician, addressing a diverse crowd with eloquence and a vision for a better future.': ['charismatic',
   'addressing',
   'diverse',
   'crowd',
   'eloquence',
   'vision'],
  'A brilliant neuroscientist, unlocking the secrets of the human brain and consciousness.': ['brilliant',
   'unlocking',
   'secrets',
   'brain'],
  'A dedicated veterinarian, caring for animals of all kinds, a healer to furry and feathered friends.': ['dedicated',
   'caring',
   'animals',
   'healer',
   'furry'],
  "A dedicated geologist, studying the Earth's geological history through rocks and formations.": ['dedicated',
   'studying',
   'history',
   'rocks'],
  'A compassionate therapist, helping individuals navigate the complexities of their inner world.': ['compassionate',
   'helping',
   'individuals',
   'navigate',
   'complexities'],
  'A charismatic actor, captivating audiences with a riveting and transformative performance.': ['charismatic',
   'captivating',
   'audiences',
   'riveting'],
  "A fearless cave explorer, delving into the depths of Earth's underground wonders.": ['fearless',
   'cave',
   'depths'],
  "A passionate marine biologist, exploring the mysteries of the ocean's depths and the creatures that inhabit it.": ['passionate',
   'marine',
   'exploring',
   'mysteries',
   'depths',
   'creatures',
   'inhabit']},
 'B': {'He plays with his dog in the park.': ['dog'],
  'The conductor guides the orchestra with precision.': ['conductor',
   'orchestra'],
  'She caresses the soft kitten.': ['caresses'],
  'The chef cooks a gourmet meal.': ['chef', 'cooks'],
  'She whispers secrets to her best friend.': ['whispers', 'secrets'],
  'She reads a book under the shade of a tree.': ['reads', 'book'],
  'He conducts experiments in the laboratory.': ['conducts', 'experiments'],
  'She researches the history of ancient civilizations.': ['researches',
   'history',
   'ancient'],
  'He fixes cars for a living.': ['fixes', 'cars'],
  'They compute the trajectory of the spacecraft.': ['compute', 'trajectory'],
  'The chef prepares a gourmet meal for the guests.': ['chef', 'meal'],
  'They skate at the ice rink.': ['skate', 'ice'],
  'He coordinates the logistics of the event.': ['coordinates', 'logistics'],
  "Let's gobble down our delicious meal.": ['gobble'],
  'He jots down notes during the meeting.': ['jots', 'notes'],
  "We'll grill burgers for dinner.": ['grill'],
  'She administers medication to her patients.': ['administers', 'medication'],
  'He programs software to solve real-world problems.': ['programs',
   'software',
   'solve'],
  'She programs software to solve real-world problems.': ['programs',
   'software',
   'solve'],
  'He skips rope during his workout.': ['skips', 'rope'],
  'She seals the envelope with care.': ['envelope'],
  'He organizes a charity fundraiser.': ['organizes', 'charity'],
  'We grin at each other in excitement.': ['grin'],
  'She implements new policies in the company.': ['implements', 'policies'],
  'He constructs a model of the solar system.': ['constructs', 'model'],
  'They collaborate on a school project.': ['school'],
  'The athlete can leap very high.': ['athlete', 'leap'],
  'He evaluates the performance of his employees.': ['evaluates',
   'performance'],
  'He smiles at strangers passing by.': ['smiles', 'strangers', 'passing'],
  'She volunteers at the local shelter.': ['volunteers'],
  'She dreams of a bright future.': ['dreams'],
  'He composes poetry in his free time.': ['composes', 'poetry'],
  'She giggles at the funny movie.': ['giggles'],
  'He skips stones across the calm lake.': ['skips', 'stones'],
  'We study together for exams.': ['study'],
  'She likes to peruse magazines at the store.': ['peruse'],
  'They compose music for a new film soundtrack.': ['compose',
   'music',
   'film'],
  'She dances gracefully on the stage.': ['dances'],
  'We linger in the park after sunset.': ['linger', 'park'],
  "She examines the patient's medical history.": ['examines'],
  'They leap over the hurdle with ease.': ['leap'],
  'They travel to new destinations every year.': ['travel', 'destinations'],
  'She rinses her face with cold water.': ['rinses', 'face'],
  'We relax on the beach during vacation.': ['relax', 'beach'],
  'They celebrate birthdays with cake.': ['celebrate', 'birthdays'],
  'They design innovative solutions for their clients.': ['design',
   'innovative',
   'solutions'],
  'She writes in her journal every night.': ['writes', 'journal'],
  'He shoves the heavy box into the truck.': ['shoves', 'box'],
  'He repairs broken appliances at home.': ['repairs', 'appliances'],
  'I smile when I see a rainbow.': ['smile'],
  "They laugh heartily at the comedian's jokes.": ['laugh'],
  'She sings her favorite song in the shower.': ['sings', 'song'],
  'They run marathons for charity.': ['run'],
  'She coordinates the logistics of the event.': ['coordinates', 'logistics'],
  'We listen to music on long car rides.': ['listen', 'music', 'car'],
  'The pilot navigates the plane through turbulent skies.': ['pilot',
   'navigates',
   'plane'],
  'The gardener prunes the bushes in the park.': ['gardener'],
  'He whispers a secret in her ear.': ['whispers'],
  'She beams with happiness.': ['beams'],
  'We watch movies on Friday nights.': ['watch', 'movies'],
  'She takes a nap on the comfy couch.': ['nap'],
  'The children tug at the rope in a game.': ['children', 'tug', 'rope'],
  "She whimpers when she's sad.": ['whimpers'],
  'She cares for injured animals.': ['cares'],
  'I smell the fresh flowers in the garden.': ['smell', 'flowers'],
  'He reads the newspaper every morning.': ['reads', 'newspaper'],
  'She evaluates the performance of her employees.': ['evaluates',
   'performance'],
  'She watches the sunset with awe.': ['watches', 'sunset'],
  'The pilot guides the plane through turbulent skies.': ['pilot', 'plane'],
  "I jump in excitement when I'm happy.": ['jump'],
  'He hikes through the forest on weekends.': ['forest'],
  'The food sizzles on the grill.': ['food', 'sizzles'],
  'The coach motivates the team to victory.': ['coach', 'team'],
  'She directs a play at the local theater.': ['directs', 'play'],
  'She loves to twirl around in her dress.': ['twirl'],
  'He skims through the newspaper quickly.': ['skims', 'newspaper'],
  'She sculpts a masterpiece from clay.': ['sculpts', 'masterpiece'],
  'He heeds advice from his parents.': ['heeds', 'advice'],
  'They embrace each other warmly.': ['embrace'],
  'The teacher teaches the students.': ['teacher'],
  'The couple gazes at the stars at night.': ['couple', 'gazes', 'stars'],
  'They hike through the forest on weekends.': ['forest'],
  'He computes complex mathematical equations.': ['computes'],
  'She photographs beautiful landscapes.': ['photographs'],
  'They marvel at the stunning sunset.': ['marvel'],
  'They jog together in the morning.': ['jog'],
  'They navigate through a dense forest.': ['navigate'],
  'They assemble a team to complete the project.': ['assemble',
   'team',
   'complete'],
  'She organizes a charity fundraiser.': ['organizes', 'charity'],
  'He rides his bike to work.': ['rides', 'bike'],
  'He plants flowers in the garden.': ['plants', 'flowers'],
  'He unlatches the gate to the garden.': ['unlatches', 'gate'],
  'He gives her a warm hug.': ['gives', 'hug.'],
  'I scrub the dishes after dinner.': ['scrub'],
  'I chat with my friend on the phone.': ['chat', 'friend'],
  'She grins from ear to ear.': ['grins', 'ear'],
  'They clap their hands in applause.': ['clap', 'hands'],
  'He marvels at the wonders of nature.': ['marvels', 'wonders'],
  'We exercise at the gym regularly.': ['gym'],
  'They analyze financial data for investment decisions.': ['analyze', 'data'],
  'They savor the taste of fine wine.': ['savor', 'taste'],
  'They cycle through the countryside.': ['cycle'],
  'She navigates the ship through stormy waters.': ['navigates',
   'ship',
   'stormy'],
  'The gardener plants flowers in the park.': ['gardener',
   'plants',
   'flowers'],
  'I chat with my friend at the cafe.': ['chat', 'friend'],
  'I gobble down my breakfast.': ['gobble'],
  'He tiptoes quietly up the stairs.': ['tiptoes'],
  'She sometimes weeps during sad movies.': ['sometimes', 'weeps'],
  'I wave to my neighbor every morning.': ['wave'],
  'The artist paints a beautiful landscape.': ['artist', 'paints'],
  'The kids doodle on their sketchbooks.': ['kids', 'doodle'],
  'She grows vegetables in her backyard.': ['grows', 'vegetables'],
  'He plays the guitar at parties.': ['guitar'],
  'I swim in the pool on hot summer days.': ['swim', 'pool'],
  'The detective interrogates the suspect.': ['detective', 'interrogates'],
  'She cooks a delicious meal for her family.': ['cooks', 'meal'],
  'He listens to music with headphones.': ['listens', 'music'],
  'We often chuckle at funny jokes.': ['chuckle'],
  'I admire the beautiful artwork.': ['admire'],
  'They enjoy a picnic in the park.': ['enjoy', 'picnic'],
  'He slurps the noodles noisily.': ['slurps', 'noodles'],
  'They sing along to their favorite songs.': ['sing'],
  'He navigates through a dense forest.': ['navigates'],
  'We giggle at silly jokes.': ['giggle'],
  'He scribbles notes in his notebook.': ['scribbles', 'notes'],
  "He coaches a kids' soccer team.": ['coaches', 'soccer'],
  'She paints colorful pictures.': ['paints'],
  'The cold breeze makes her shiver.': ['breeze', 'makes', 'shiver.'],
  "Let's take a stroll in the park.": ['stroll'],
  "They whimper when they're tired.": ['whimper'],
  'The kids frolic in the backyard.': ['kids', 'frolic'],
  'He admires the beautiful artwork.': ['admires'],
  'They bake cookies for the holidays.': ['bake', 'cookies'],
  'I dream of traveling the world.': ['dream'],
  'The baker mixes the ingredients for the cake.': ['baker',
   'mixes',
   'ingredients'],
  'A deer with antlers.': ['deer'],
  'A cat playing with a ball of yarn.': ['cat', 'ball'],
  'A platypus in a stream.': ['platypus'],
  'A giraffe reaching for leaves.': ['giraffe', 'reaching'],
  'A scientist in a lab coat.': ['scientist', 'lab'],
  'A police officer on patrol.': ['police', 'officer'],
  'A refrigerator with magnets.': ['refrigerator'],
  'A horse with a saddle.': ['horse'],
  'A phone with a text message.': ['phone'],
  'A kangaroo with a joey.': ['kangaroo'],
  'A fish leaping out of water.': ['fish', 'leaping'],
  'A hamster running on a wheel.': ['hamster', 'running'],
  'A library with a reading nook.': ['library'],
  'A computer with multiple screens.': ['computer'],
  'A cat purring on a lap.': ['cat', 'purring'],
  'A camera capturing a breathtaking landscape.': ['camera',
   'capturing',
   'breathtaking'],
  'A penguin sliding on ice.': ['penguin'],
  'A school bus picking up kids.': ['school'],
  'An octopus with tentacles.': ['octopus'],
  'A jellyfish drifting in the sea.': ['jellyfish'],
  'A chef preparing a gourmet meal.': ['chef'],
  'A chef tasting a dish.': ['chef'],
  'A friend sharing a secret.': ['friend'],
  'A pig rolling in mud.': ['pig', 'rolling'],
  'A musician composing a song.': ['musician', 'composing'],
  'A turtle sunbathing on a rock.': ['turtle'],
  'A raccoon searching through garbage.': ['raccoon', 'searching'],
  'A bird singing in a tree.': ['bird'],
  'A crocodile in a swamp.': ['crocodile'],
  'A camera capturing a smile.': ['camera', 'capturing'],
  'A wallet overflowing with cash.': ['wallet'],
  'A bear catching fish in a river.': ['bear', 'fish'],
  'A goat balancing on a log.': ['goat'],
  'A bird building a nest.': ['bird', 'building'],
  'A gorilla swinging from vines.': ['gorilla'],
  'A bee collecting nectar.': ['bee', 'collecting'],
  'A porcupine with sharp quills.': ['porcupine'],
  'A car parked in a garage.': ['car'],
  'A pen crafting a masterpiece.': ['pen', 'crafting'],
  'An umbrella shielding from heavy rain.': ['umbrella'],
  'A peacock displaying its feathers.': ['peacock', 'its'],
  'A fox with a bushy tail.': ['fox'],
  'A hedgehog curled up in a ball.': ['hedgehog', 'curled'],
  'A cow grazing in a field.': ['cow', 'grazing'],
  'A mechanic fixing an engine.': ['mechanic'],
  'A lion resting in the shade.': ['lion'],
  'A tiger prowling in the grass.': ['tiger'],
  'An athlete scoring a goal.': ['athlete'],
  'A parrot talking.': ['parrot'],
  'A writer with a typewriter.': ['writer'],
  'A snake coiled on a branch.': ['snake'],
  'A mirror reflecting a smiling face.': ['mirror'],
  'A meerkat standing on its hind legs.': ['meerkat',
   'standing',
   'its',
   'hind'],
  'A clock striking midnight.': ['clock', 'striking'],
  'An artist with a paintbrush.': ['artist'],
  'A chair at a grand dining table.': ['chair', 'dining'],
  'A fish in a pond with lily pads.': ['fish', 'pond'],
  'A cheetah sprinting across the savanna.': ['cheetah'],
  'A television with a remote.': ['television'],
  'A butterfly on a flower petal.': ['butterfly', 'flower'],
  'A horse jumping over a hurdle.': ['horse'],
  'A dolphin leaping from the water.': ['dolphin', 'leaping'],
  'A bicycle parked near a scenic trail.': ['bicycle'],
  'A lamp illuminating a cozy room.': ['lamp'],
  'A chair next to a fireplace.': ['chair'],
  'A clock with moving hands.': ['clock', 'moving'],
  'A firefighter rescuing a kitten.': ['firefighter', 'rescuing'],
  'A beach with a sandcastle.': ['beach'],
  'A musician strumming a guitar.': ['musician'],
  'A table set for a feast.': ['table', 'set'],
  'A book open to an exciting chapter.': ['book', 'open'],
  'A squirrel gathering acorns.': ['squirrel'],
  'A flamingo wading in water.': ['flamingo'],
  'A rabbit nibbling on carrots.': ['rabbit'],
  'A lobster in a seafood tank.': ['lobster'],
  'A dog chasing a frisbee.': ['dog'],
  'A seagull flying over the ocean.': ['seagull'],
  'A shark swimming in the deep.': ['shark', 'swimming'],
  'A dog fetching a stick.': ['dog', 'fetching'],
  'A doctor examining a patient.': ['doctor'],
  'An astronaut in a spacesuit.': ['astronaut'],
  'A zebra with black and white stripes.': ['zebra'],
  'An eagle swooping down.': ['eagle'],
  'A television showing breaking news.': ['television'],
  'A firefighter climbing a ladder.': ['firefighter'],
  'A spider spinning a web.': ['spider'],
  'A student taking notes.': ['student'],
  'A chameleon changing colors.': ['chameleon'],
  'A phone ringing loudly.': ['phone'],
  'A car speeding down the highway.': ['car'],
  'A rhinoceros with a horn.': ['rhinoceros'],
  'An owl perched on a branch.': ['owl', 'perched'],
  'A refrigerator filled with fresh groceries.': ['refrigerator', 'filled'],
  'A chicken roosting in a coop.': ['chicken'],
  'A teacher at a chalkboard.': ['teacher'],
  'A sheep in a pasture.': ['sheep'],
  'A wallet with money.': ['wallet'],
  'A computer with code on the screen.': ['computer'],
  'A doctor writing a prescription.': ['doctor'],
  'A book with a bookmark.': ['book']}
  }

# %%
import random

def generate_puzzle(level):
    if level not in ['A', 'B', 'C', 'S']:
        return "Invalid level. Please choose from 'S', 'A', 'B', or 'C'."   
   
    if level not in sentences:
        return "Invalid level. Please choose from 'S', 'A', 'B', or 'C'."
    
    random_sentence = random.choice(list(sentences[level].keys()))
    words_to_replace = sentences[level][random_sentence]

    # Randomly select a word to replace from the sentence
    word_to_replace = random.choice(words_to_replace)

    # Replace the word with '[missing_word]'
    puzzle_sentence = random_sentence.replace(word_to_replace, '[missing_word]')

    return puzzle_sentence, word_to_replace

generate_puzzle('C')
# Out:
# ('They [missing_word] in the pool on hot summer days.', 'swim')

# %%
import requests
import json

url = "https://stablediffusionapi.com/api/v3/text2img"

payload = json.dumps({
  "key": "Panrscrg2OTgEFZMQBkgCm2VUv1XqyKgyx1G1AQgpFaV722awQqc5goZf9Md",
  "prompt": "ultra realistic portrait of ((ottman islamic empire and buildings))",
  "negative_prompt": None,
  "width": "1024",
  "height": "1024",
  "samples": "1",
  "num_inference_steps": "20",
  "seed": 42358722,
  "guidance_scale": 7.5,
  "safety_checker": "yes",
  "multi_lingual": "no",
  "panorama": "no",
  "self_attention": "no",
  "upscale": "yes",
  "embeddings_model": None,
  "webhook": None,
  "track_id": None
})

headers = {
  'Content-Type': 'application/json'
}

response = requests.request("POST", url, headers=headers, data=payload)
response_dict = json.loads(response.text)
image = response_dict['output'][0]
print(image)
# Out:
# Vertex Distance from Source:
# 0 		 0
# 1 		 5
# 2 		 7
# 3 		 6
# 4 		 5
# 5 		 4
